# %% [markdown]
# <h1> Creating dataset </h1>

# %%
from sqlalchemy import create_engine , text
from sqlalchemy.engine import URL

# %%
# create engine
def get_engine(url):
    engine = create_engine(url)
    return engine

# create database
def create_database(engine):
    with engine.connect() as conn:
        conn.execute(text("CREATE DATABASE Banking_Analytics"))
        conn.commit()
    print("database created Successfully")

# call functions
url = URL.create(
    "mysql+pymysql",
    username="root",
    password="Mysql@123",
    host="localhost",
    port=3306
)

# engine = get_engine(url)
# create_database(engine)

# %% [markdown]
# <h2> Step 2: Connect to Banking_Analytics </h2>

# %%
url = URL.create(
    drivername = "mysql+pymysql",
    username = "root",
    password = "Mysql@123",
    host = "localhhost",
    port = 3306,
    database = "Baking_Analytics"
)
engine = create_engine(url)
